# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/LVC Datasets/Lesson_4/blood_pressure.csv')
df.head()
# Out:
#    patient   sex agegrp  bp_before  bp_after
# 0        1  Male  30-45        143       153
# 1        2  Male  30-45        163       170
# 2        3  Male  30-45        153       168
# 3        4  Male  30-45        153       142
# 4        5  Male  30-45        146       141

# %%
df.columns
# Out:
# Index(['patient', 'sex', 'agegrp', 'bp_before', 'bp_after'], dtype='object')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['bp_before'].plot()
# Out:
# <Axes: >

# %%
df['bp_after'].plot(legend=True)
# Out:
# <Axes: >

# %%
# Change the time of the figure and axis of the columns
df.plot(x='bp_before', y='bp_after', kind= 'scatter', legend=True)
# Out:
# <Axes: xlabel='bp_before', ylabel='bp_after'>

# %%
# Change the size of the figer and add title
df.plot(title="Sample Blood Pressure", figsize=(15, 10))
# Out:
# <Axes: title={'center': 'Sample Blood Pressure'}>

# %%
df['bp_after'].plot(kind='box', title='Box Plot')
# Out:
# <Axes: title={'center': 'Box Plot'}>

# %%
df['bp_after'].plot(kind='hist', title='Histogram Plot')
# Out:
# <Axes: title={'center': 'Histogram Plot'}, ylabel='Frequency'>
